# %% [markdown]
# ## HTML Page Read and Upload

# %%
# Import useful libraries and classes.
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup

# %%
#html page upload and read in web_page variable.
my_url=  "https://www.flipkart.com/search?p%5B%5D=facets.brand%255B%255D%3DSamsung&sid=tyy%2F4io&sort=recency_desc&wid=1.productCard.PMU_V2_1"
# my_rls = 'https://www.flipkart.com/search?p%5B%5D=facets.brand%255B%255D%3DSamsung&sid=tyy%2F4io&sort=recency_desc&wid=1.productCard.PMU_V2_1%22'
web_page= uReq(my_url)
page_html= web_page.read()

# %% [markdown]
# ## Parsing

# %%
#html parser. It is to beautify the HTML code.
page_soup= soup(page_html)
page_soup
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# ## Extraction of information

# %%
#read class attribute from web page in containers variable.
# Print the length of containers.
containers= page_soup.findAll("div", {"class": "lister-item mode-advanced"})
print(len(containers))
# Out:
# 0

# %%
# Extract the model name of 6th phone in the list.
# Extract the 6th container from the list.
sixth_container = containers[5]

# Find the model name element within the container and extract its text.
model_name = sixth_container.find("a", {"class": "_1fQZEK"}).text

# Print the extracted model name.
print(model_name)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[37], line 3
#       1 # Extract the model name of 6th phone in the list.
#       2 # Extract the 6th container from the list.
# ----> 3 sixth_container = containers[5]
#       5 # Find the model name element within the container and extract its text.
#       6 model_name = sixth_container.find("a", {"class": "_1fQZEK"}).text
#
# IndexError: list index out of range

# %%
# how many elements does 'tVe95H' class contained in it?

# %%
# Read the camera specification of 8th phone in the list.
